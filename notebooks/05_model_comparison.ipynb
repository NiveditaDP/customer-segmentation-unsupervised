# %%
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("../results/cluster_plots/customer_clusters.csv")

df.head()
# Out:
#         Age    Gender  Education Level  Geographic Information  Occupation  \
# 0 -1.401980 -1.028344        -1.365141                0.547943   -0.420389
# 1 -1.203033  0.972437         0.057168               -0.637324    0.351183
# 2 -1.004085 -1.028344        -1.365141                1.041804   -0.420389
# 3 -1.600928  0.972437        -0.653987                1.140576   -0.420389
# 4 -1.269349 -1.028344        -0.653987                1.733210    0.351183
#
#    Income Level  Interactions with Customer Service  Insurance Products Owned  \
# 0     -0.333617                            1.449844                 -0.552061
# 1     -0.780348                           -1.293483                 -1.241050
# 2     -0.241996                           -0.607651                  0.136927
# 3     -0.528975                           -1.293483                 -0.552061
# 4     -1.199821                           -1.293483                  0.825916
#
#    Preferred Contact Time  Preferred Language  Segmentation Group  Cluster
# 0               -1.621059           -1.419718            1.270568        2
# 1                0.484279           -0.647116            1.270568        1
# 2               -0.217500            0.125487           -0.120496        1
# 3               -0.919279           -0.647116           -0.120496        1
# 4                1.186059           -1.419718           -0.816028        1

# %%
X = df.drop("Cluster", axis=1)

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
score = silhouette_score(X_scaled, df["Cluster"])

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.058519015550278566

# %%
# compare silhouette scores
kmeans_score = float(open("../results/metrics/kmeans_silhouette.txt").read().split(": ")[1])

# other models scores
# save them to metrics folder similarly if computed
print("KMeans Silhouette Score:", kmeans_score)
# print DBSCAN or Hierarchical if saved
